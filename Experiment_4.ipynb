# %%
# Experiment 4 :
# Naman Bothra
# PRN : 25070123078


# creation of set
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
#sets do not allow duplicates
thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
# in the below condition either 1 or true will be printed not both of them because in sets true is considerd equal to one and set does not allow duplicates
thisset = {"apple", "banana", "cherry", True, 1, 2}
print(thisset)
# Out:
# {'banana', True, 2, 'apple', 'cherry'}

# %%
# To check membership
thisset = {"apple", "banana", "cherry"}

print("banana" in thisset)
print("grapes" in thisset)
# Out:
# True
# False

# %%
# Once a set is created, you cannot replace it's item,
# but you can add extra items

thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
thisset.add(2)

print(thisset)
# Out:
# {2, 'orange', 'cherry', 'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("banana")
print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
# set opertaions
a = {1,2,3,4,5}
b = {3,4,5,6,7}

print("Union:", a|b)
print("Intersection:", a&b)
print("Difference1:", a-b)
print("Difference2:", b-a)
print("Symmetric Difference:", a^b)
# Out:
# Union: {1, 2, 3, 4, 5, 6, 7}
# Intersection: {3, 4, 5}
# Difference1: {1, 2}
# Difference2: {6, 7}
# Symmetric Difference: {1, 2, 6, 7}

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'cherry', 'apple'})
# <class 'frozenset'>

# %%
name = ["a","b","c","d","b","c"]
name = set(name)
print(name)
# Out:
# {'c', 'b', 'd', 'a'}

# %%
a = {"maths", "biology", "physics"}
b = {"biology", "hindi", "literature"}
c = {"biology", "maths", "chemistry"}

print("common subjects=", a & b & c)
# Out:
# common subjects= {'biology'}

# %%
cricket = {"virat", "rohit", "dhoni", "rahul"}
football = {"virat", "rohit", "neymar", "messi"}
print("Cricket=",cricket - football)
print("Football=",football - cricket)
print("Cricket & Football=",cricket ^ football)
print(cricket & football)
# Out:
# Cricket= {'dhoni', 'rahul'}
# Football= {'neymar', 'messi'}
# Cricket & Football= {'rahul', 'messi', 'neymar', 'dhoni'}
# {'virat', 'rohit'}

# %%
all_students = {"a","b","c","d","e","f"}
present = {"a","b","c"}
print("absent=",all_students - present)
# Out:
# absent= {'e', 'd', 'f'}

# %%
subjects = {"maths", "english", "physics", "chemistry", "biology"}
subjects.remove("physics")
print(subjects)
# Out:
# {'biology', 'maths', 'english', 'chemistry'}
